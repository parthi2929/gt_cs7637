# %% [markdown]
# # Frames
#
# Common Sense Reasoning
#
# Frames are knowledge structures with Slots and Fillers
#
# ## Example
#
# ### Ashok ate a frog
#
# | Ate  | |
# |---|---|
# | subject | Ashok |
# object | a frog
# location |
# time |
# utensils |
# object-alive | false
# object-is | in-subject
# subject-mood | happy
#
# ## Complex Frames
#
# ![2019-06-07_19h46_30.png](attachment:2019-06-07_19h46_30.png)

# %% [markdown]
# ## Properties
#
# * Stereotypical
# * Default values (and exception management)
# * Inheritance (animal to ant, human etc)
# * Like OOP, there could also be instances

# %% [markdown]
# ## Frames and Semantic Networks
#
# ..are closely related..
#
# ![2019-06-07_19h55_57.png](attachment:2019-06-07_19h55_57.png)

# %% [markdown]
# ## Extract Frames
#
# ![2019-06-07_20h06_12.png](attachment:2019-06-07_20h06_12.png)
