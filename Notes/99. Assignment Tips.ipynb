# %% [markdown]
# ## Semantic Nets

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('LyXZQFfN3L0')

# %% [markdown]
# ## Generate & Test

# %%
YouTubeVideo('ClQvyiJz6as')

# %% [markdown]
# ## Problem Reduction

# %%
YouTubeVideo('NoHrxa1j4NA')

# %% [markdown]
# ## Production Systems

# %%
YouTubeVideo('hWUUVHzhilE')

# %% [markdown]
# ## Frames

# %%
YouTubeVideo('CNdkeB78nIM')

# %% [markdown]
# ## Learning By Recording Cases

# %%
YouTubeVideo('ajjMx5iuhmU')

# %% [markdown]
# ## Case Based Reasoning

# %%
YouTubeVideo('g9vSmdrc98s')
